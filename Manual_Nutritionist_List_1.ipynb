# %%
# Building a partial (50-row) verified/partially-verified list of Georgia non-pediatric / mixed-practice nutritionists

import pandas as pd

data = [{"Name":"Susan Boekel","Business":"Ingrid Knight, RD and Associates, Inc.","Email":"seboekel@yahoo.com","Phone":"404-725-0808","City":"Atlanta","Notes":"Pediatric & family nutrition, telehealth","Source":"web"},
{"Name":"Eugenia Couchoud-Wilkinson","Business":"NutritionECW, LLC","Email":"ecw@nutritionecw.com","Phone":"678-407-2159","City":"Johns Creek","Notes":"Pediatrics, weight management, complex nutrition needs","Source":"web"},
{"Name":"Melissa Hoover","Business":"Ignite Nutrition Services","Email":"melissa@ignite-nutrition.com","Phone":"478-219-5909","City":"Forsyth","Notes":"Weight management, pediatrics, telehealth","Source":"web"},
{"Name":"Karen Heiman","Business":"Orozco Nutrition","Email":"karen.heiman@orozconutrition.com","Phone":"678-568-4717","City":"Lawrenceville","Notes":"Pediatrics, weight management, telehealth","Source":"web"},
{"Name":"Meagan Horne","Business":"NutritionECW, LLC","Email":"appointments@nutritionecw.com","Phone":"678-407-2159","City":"Johns Creek","Notes":"Clinical nutrition, pediatric complex conditions, telehealth","Source":"web"},
{"Name":"Amber Johnson","Business":"Harmony Nutrition","Email":"amber@harmonynutritionatl.com","Phone":"678-554-7576","City":"Alpharetta","Notes":"Pediatrics, weight management, telehealth","Source":"web"},
{"Name":"Kate Keirsey","Business":"Wellfed Family Nutrition","Email":"kate@wellfed.family","Phone":"678-378-0190","City":"(telehealth / Atlanta area)","Notes":"Pediatric & family nutrition, telehealth","Source":"web"},
{"Name":"Gloria Ochoa-Andia","Business":"Goodness Nutrition Center, LLC","Email":"gloria@goodnessnutritioncenter.com","Phone":"678-680-3261","City":"Lawrenceville","Notes":"Pediatrics, lactation, diabetes education, telehealth","Source":"web"},
{"Name":"Safa Nooromid","Business":"Nooromid Nutrition Consulting Group","Email":"safa@atlnutrition.com","Phone":"770-971-9234","City":"(telehealth / Atlanta area)","Notes":"Pediatrics, sports nutrition, telehealth","Source":"web"},
{"Name":"David Orozco","Business":"Orozco Nutrition","Email":"david.orozco@orozconutrition.com","Phone":"678-568-4717","City":"Lawrenceville","Notes":"Adult & pediatric nutrition, sports nutrition, telehealth","Source":"web"},
{"Name":"Tiffany Barrett","Business":"Winship Cancer Institute / Emory","Email":"(see Emory Winship)","Phone":"404-778-5646","City":"Atlanta","Notes":"Oncology nutrition services (Winship Dietitians)","Source":"web"},
{"Name":"Karen Bartlett, RDN, LD","Business":"Ingrid Knight, RD and Associates, Inc","Email":"kbartlettrdn@gmail.com","Phone":"678-997-5001","City":"na","Notes":"Sports Nutrition, Pre-Diabetes, Hyperlipidemia,","Source":"web"},
{"Name":"Alicia Simpson, MS, RD, IBCLC, LD","Business":"Pea Pod Nutrition","Email":"alicia@peapodnutrition.org","Phone":"678-607-6052","City":"Decatur","Notes":"Eating, Family Nutrition, Food Allergies,","Source":"web"},
{"Name":"Alicia Simpson, MS, RD, IBCLC, LD","Business":"Pea Pod Nutrition","Email":"info@peapodnutrition.org","Phone":"678-607-6052","City":"Decatur","Notes":"Eating, Family Nutrition, Food Allergies,","Source":"web"},
{"Name":"Robin Staub, RDN, LD","Business":"Healthy Habits Nutrition Consulting","Email":"robstau@aol.com","Phone":"706-546-7136","City":"Athens","Notes":"Nutrition, Thyroid Disease, Pre-Diabetes","Source":"web"},
{"Name":"Claudia Winter, MS, RDN, LD, CDCES","Business":"NutritionECW, LLC Medical Nutrition Therapy","Email":"ecw@nutritionecw.com","Phone":"678-407-2159","City":"Johns Creek","Notes":"Diabetes, Insulin Therapy & Continuous Glucose ","Source":"web"},
{"Name":"Samantha Cullen","Business":"Nourish Family Nutrition Therapy","Email":"info@nourishfamily.com","Phone":"678-971-0154","City":"Atlanta","Notes":"Eating Disorders and Intuitive Eating","Source":"web"},
{"Name":"Patrick Traynor, PHD, MPH, RD, CPT","Business":"MNT Scientific, LLC","Email":"info@mntscientific.com","Phone":"470-517-7943","City":"Atlanta","Notes":"Weight Loss/Weight Management, Diet and Nutrition and Diabetes","Source":"web"},
{"Name":"Danielle Hendrix","Business":"Health Loft","Email":"info@healthloftco.com","Phone":"346-666-7394","City":"Atlanta","Notes":"All Foods Fit and non-diet approach","Source":"web"},
{"Name":"Gregory Lafortune","Business":"Gregory Lafortune","Email":"nutrition@gregorylafortune.com","Phone":"678-855-8441","City":"Peachtree City","Notes":"Men's Health, Diabetes and Health Coaching","Source":"web"},
{"Name":"Laura Marchese MS RD LD","Business":"Nourishing Nutrition Consulting, LLC","Email":"Laura@NourishingNutritionConsulting.com","Phone":"470-467-8273","City":"Peachtree City","Notes":"GI Disorders, Eating Disorders, Hypertension, High Cholesterol & Heart Disease","Source":"web"},
{"Name":"Meagan Horne, MBA, MHA, RD, LD, CNSC, CPHQ","Business":"NutritionECW, LLC","Email":"appointments@nutritionecw.com","Phone":"678-407-2159","City":"Johns Creek","Notes":"Clinical nutrition, pediatric complex conditions, telehealth","Source":"web"},
{"Name":"Amber Johnson, MS, RDN, LD","Business":"Harmony Nutrition","Email":"info@harmonynutritionatl.com","Phone":"678-554-7576","City":"Alpharetta","Notes":"Pediatrics, weight management, telehealth","Source":"web"},
{"Name":"Kate Keirsey, MS, RD","Business":"Wellfed Family Nutrition","Email":"kate@wellfed.family","Phone":"678-378-0190","City":"(telehealth / Atlanta area)","Notes":"Pediatric & family nutrition, telehealth","Source":"web"},
{"Name":"Gloria Ochoa-Andia, RDN, LD, CDCES, IBCLC","Business":"Goodness Nutrition Center, LLC","Email":"gloria@goodnessnutritioncenter.com","Phone":"678-680-3261","City":"Lawrenceville","Notes":"Pediatrics, lactation, diabetes education, telehealth","Source":"web"},
{"Name":"Safa Nooromid, RDN, LD","Business":"Nooromid Nutrition Consulting Group","Email":"safa@atlnutrition.com","Phone":"770-971-9234","City":"(telehealth / Atlanta area)","Notes":"Pediatrics, sports nutrition, telehealth","Source":"web"},
{"Name":"David Orozco, MS, RDN, LD, CIEC","Business":"Orozco Nutrition","Email":"david.orozco@orozconutrition.com","Phone":"678-568-4717","City":"Lawrenceville","Notes":"Adult & pediatric nutrition, sports nutrition, telehealth","Source":"web"},
{"Name":"Tiffany Barrett, MS, RD, CSO, LD","Business":"Winship Cancer Institute / Emory","Email":"(see Emory Winship)","Phone":"404-778-5646","City":"Atlanta","Notes":"Oncology nutrition services (Winship Dietitians)","Source":"web"},
{"Name":"Tenika Miles","Business":"Scaled Balance Nutrition","Email":"scalednutrition@gmail.com","Phone":"(678)661-5027","City":"Peachtree","Notes":"Wellness Counseling","Source":"web"},
{"Name":"Lauren Seaman","Business":"Nutrition Healthworks of GA LLC","Email":"admin@nutritionhealthworks.com","Phone":"912-494-6661","City":"Savannah","Notes":"Women's Health","Source":"web"},
{"Name":"Kelsey Shepperd","Business":"Shepperding Wellness","Email":"Shepperdingwellness@gmail.com","Phone":"678-304-2192","City":"Dallas","Notes":"Food Sensitivity, Health Coaching and Weight Loss/Weight Management ","Source":"web"},
{"Name":"Kate Iampietro Keirsey, MS, RD, LD","Business":"Well Fed Family","Email":"info@wellfed.family","Phone":"470-824-8891","City":"Atlanta","Notes":"Heart Health, Weight Loss/Weight Management and Women's Health ","Source":"web"},
{"Name":"Melissa Reid, MS, RDN","Business":"Indulge in Nutrition, LLC","Email":"support@indulgeinnutrition.com ","Phone":"762-583-8875","City":"Columbus","Notes":"Weight Loss/Weight Management, Health Coaching ","Source":"web"},
{"Name":"Alane Wincek","Business":"Nutritionally Yours","Email":"alanepnd@gmail.com","Phone":"678-372-2913","City":"Alpharetta","Notes":"Wellness Counseling, Food Allergy and Weight Loss/Weight Management","Source":"web"},
{"Name":"Jennifer Shapiro","Business":"Jennifer Shapiro Nutrition","Email":"jennifershapirord@gmail.com","Phone":"321-473-4965","City":"Atlanta","Notes":"Pregnancy, Postpartum Nutrition and Diabetes","Source":"web"},
{"Name":"Jadeda Hooks","Business":"Kidney Nutrition Specialist LLC","Email":"jhooks@getnutrition4kidneys.com","Phone":"470-205-0119","City":"Newnan","Notes":"Kidney Disease/Renal, Cholesterol and Diabetes","Source":"web"},
{"Name":"Sondra Tackett","Business":"Nutrition HealthWorks","Email":"admin@nutritionhealthworks.com","Phone":"704-741-7898","City":"Savannah","Notes":"Weight Loss/Weight Management, Diabetes and Gastrointestinal","Source":"web"},
{"Name":"Rachel Stefan","Business":"The Nutrition Clinic for Digestive Health ","Email":"hello@digestiontherapy.com","Phone":"678-424-6520","City":"Atlanta","Notes":"Functional Medicine Nutritionist","Source":"web"},
{"Name":"Courtney Plush","Business":"Courtney Plush Nutrition","Email":"courtney@courtneyplushnutrition.com","Phone":"610-506-0643","City":"Atlanta","Notes":"VegetarianWellness Counseling","Source":"web"},
{"Name":"Alexis L. Martinez","Business":"Healthy Brown Girl","Email":"alexis@healthybrowngirl.com","Phone":"770-580-0008","City":"Powder Springs","Notes":"Behavior Modification Depression Diet and Nutrition Emotional Eating associated with ADHD","Source":"web"},
{"Name":"Betsy Thurston, RD","Business":"Betsy Thurston Nutrition","Email":"betsy@betsythurstonrd.com","Phone":"404 295 1415","City":"Marietta","Notes":"Weight Loss/Weight Management Eating Disorders Diet and Nutrition","Source":"web"},
{"Name":"Val Schonberg","Business":"Midlife Health","Email":"Val@ValSchonberg.com","Phone":"404-680-6032","City":"Atlanta","Notes":"Sports Nutrition, Eating Disorders","Source":"web"},
{"Name":"Mercy Aremu","Business":"YourFide","Email":"Info@YourFide.com","Phone":"770-881-8651","City":"Snellville","Notes":"Heart disease/ Kidney disease/pre diabetes- Diabetes/ high cholesterol/Crohn/ PCOS/ Gout/ Autoimmune-diseases/","Source":"web"},
{"Name":"Sonali Sadequee","Business":"Sustainable Wellness","Email":"class@sustainable-wellness.com","Phone":"678-733-9651","City":"Decatur","Notes":" Vegan, Gastrointestinal ","Source":"web"},
{"Name":"Robin Staub-Grundstein, RD LD","Business":"Healthy Habits Nutrition Consulting","Email":"robstau@aol.com","Phone":"706-546-7136","City":"Athens","Notes":"weight loss, weight gain, eating disorder","Source":"web"},
{"Name":"Jerlyn Jones","Business":"The Lifestyle Dietitian LLC","Email":"info@thelifestyledietitian.com","Phone":"678-568-1426","City":"Atlanta","Notes":"joint pain, migraines, PCOS, irritable bowel syndrome","Source":"web"},
{"Name":"Alissa Palladino, MS, RDN, LD","Business":"Alissa Palladino Nutrition","Email":"apalladinordn@gmail.com","Phone":"917-309-6306","City":"Atlanta","Notes":"nutrition, fitness and wellness topics","Source":"web"},
{"Name":"Rachel Brandeis, MS, RD","Business":"Rachel Brandeis","Email":"rachel@rachelrd.com","Phone":"770-752-4984","City":"Atlanta","Notes":"Polycystic Ovarian Syndrome (PCOS) nutrition education program","Source":"web"},
{"Name":"Marisa Moore, MBA, RDN, LD","Business":"Marisa Moore","Email":"marisa@marisamoore.com","Phone":"NA","City":"Atlanta","Notes":"vegetarian recipes, credible nutrition information ","Source":"web"},
{"Name":"Julane R. Contursi","Business":"Nutrition Concepts Consulting","Email":"info@nutritionconceptsconsulting.com","Phone":"470-834-5432","City":"Smyrna","Notes":"Health, fitness, wellness","Source":"web"},
{"Name":"Charlene Wilson","Business":"Wilson Nutrition","Email":"charlene@wilsonnutrition.com","Phone":"470-202-1758","City":"Suwanee","Notes":"overall wellness","Source":"web"},
{"Name":"Danielle Lewis","Business":"DL Dietetics","Email":"dlewisRD@gmail.com","Phone":"678-236-2164","City":"Atlanta","Notes":"functional nutrition","Source":"web"},
{"Name":"Jennifer Hnat","Business":"Nutrition Atlanta","Email":"jennifer@nutritionatlanta.com","Phone":"404-353-3482","City":"Atlanta","Notes":"specific nutrition intervention","Source":"web"},
{"Name":"Denise Pickett-Bernard","Business":"Dr. Dee Nutrition","Email":"info@drdeenutrition.com","Phone":"954-309-5366","City":"Roswell","Notes":"optimal health, functional medicine","Source":"web"},
{"Name":"Regina Saxton","Business":"Starting Point Wellness","Email":"regina@eatingwellagingwell.com","Phone":"678-372-2346","City":"Suwanee","Notes":"food sensitivities, intuitive eating, and chronic symptoms","Source":"web"},
{"Name":"Eat Well Georgia","Business":"Eat Well Georgia","Email":"admin@eatwellgeorgia.com","Phone":"770-693-8618","City":"Smyrna","Notes":"self regulate nutrition, sensory issues","Source":"web"},
{"Name":"Emily Harrison","Business":"Nutrition for Great Performances","Email":"echarrison2@gmail.com","Phone":"","City":"Atlanta","Notes":"Nutrition for wellness","Source":"web"},
{"Name":"Heather Lasco","Business":"Confidently Nourished","Email":"info@confidentlynourished.co ","Phone":"404-999-3149","City":"Atlanta","Notes":"General Nutrition, Wellness,Eating Disorders,Diabetes, Hypoglycemia","Source":"web"},
{"Name":"Sarah Metzger","Business":"Sarah Metzger Nutrition","Email":"smketonutrition@gmail.com","Phone":"","City":"Atlanta","Notes":"Diabetes, Hypoglycemia,Neurology","Source":"web"},
{"Name":"Val Schonberg","Business":"EnlightenU Nutrition Consulting","Email":"Val@ValSchonberg.com","Phone":"404-680-6032","City":"Atlanta","Notes":"Wellness,Eating Disorders,Stroke","Source":"web"},
{"Name":"YourFide Dietitian","Business":"YourFide Dietitian","Email":"info@yourFide.com","Phone":"770-881-8651","City":"Atlanta","Notes":"Kidney, Medical, and prenatal nutrition","Source":"web"},
{"Name":"Christina Ellenberg","Business":"Dietician Dish","Email":"Christina@DietitianDish.com","Phone":"470-344-6492","City":"Atlanta","Notes":"medical conditions, disease prevention","Source":"web"},
{"Name":"Darby Bier","Business":"Pink Rose Nutrition","Email":"darby.bier@pinkrosenutrition.com","Phone":"404-372-2372","City":"Roswell","Notes":"fertility, pregnancy, postpartum","Source":"web"},
{"Name":"Sarah Hembree","Business":"Sarah Hembree Nutrition Counseling and Wellness Coaching","Email":"hembreesarah1@gmail.com","Phone":"229-343-5790","City":"Allentown","Notes":"clinical dietetics","Source":"web"},
{"Name":"Fit Fresh Foodie","Business":"Fit Fresh Foodie","Email":"bre@fitfreshfoodie.com","Phone":"231-794-9715","City":"Perry","Notes":"dietary changes, overall wellness","Source":"web"},
{"Name":"Kajal J Patel","Business":"SVAST Nutrition","Email":"info@svastnutrition.com","Phone":"478-217-1452 ","City":"Warner Robins","Notes":"Whole food nutrition for healing","Source":"web"},
{"Name":"Denise Fields","Business":"Denise Fields Nutrition","Email":"denisefieldsnutrition@gmail.com","Phone":"229-630-3833","City":"Valdosta","Notes":"weight management, medical, corporate wellness","Source":"web"},
{"Name":"Jenna Sullivan","Business":"Jenna Sullivan, Holistic Nutritionist and Yoga Instructor","Email":"jenna@liveradiant.com","Phone":"619-770-9752","City":"Griffin","Notes":"weightloss nutrition, yoga","Source":"web"},
{"Name":"Teresa Roberson","Business":"My Nutrition Source","Email":"support@mynutritionsource.com","Phone":"770-631-3297","City":"Peachtree City","Notes":"stress, wellness","Source":"web"},
{"Name":"Alex Briceno, RD, CSP, LD","Business":"Atlanta Pediatric Nutrition, Inc.","Email":"admin@atlantapediatricnutrition.com","Phone":"404-543-3897","City":"Atlanta","Notes":"Nutrition, Picky Eating, Family Nutrition, ","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"},
{"Name":"","Business":"","Email":"","Phone":"","City":"","Notes":"","Source":"web"}
]



# -------------------- SAVE Dataframe --------------------

df = pd.DataFrame(data)

# how many rows saved?
print(f"Total rows: {len(df)}")
# Out:
# Total rows: 89

# %%
# REMOVE DUPLICATES

# Remove duplicate Names (keep the first occurrence)
df = df.drop_duplicates(subset="Name", keep="first").reset_index(drop=True)

#remove duplicate Emails
df = df.drop_duplicates(subset="Email", keep="first").reset_index(drop=True)

# Optional: confirm it worked
print(f"Removed duplicates. New total rows: {len(df)}")
# Out:
# Removed duplicates. New total rows: 60

# %%
# REMOVE PEDIATRIC BUSINESSES

# Remove "Business":"Atlanta Pediatric Nutrition, Inc."
df = df[~df['Business'].str.contains('Atlanta Pediatric Nutrition, Inc', case=False, na=False)].reset_index(drop=True)

# Remove rows where "Business" and "Notes" contains "Pediatric"
df = df[~df['Notes'].str.contains('Pediatric nutritionist', case=False, na=False)].reset_index(drop=True)

# Optional: check the result
print(f"Rows after removing pediatric businesses: {len(df)}")
# Out:
# Rows after removing pediatric businesses: 59

# %%
# ORGANIZE IN ALPHABETICAL ORDER

# Sort alphabetically by Name
df = df.sort_values(by="Name", ignore_index=True)

# %%
#save to csv
df.to_csv("ga_nutritionists_1.csv", index=False)
print(f"✅ Saved {len(df)} records to 'ga_nutritionists_1.csv'")
# Out:
# ✅ Saved 59 records to 'ga_nutritionists_1.csv'
